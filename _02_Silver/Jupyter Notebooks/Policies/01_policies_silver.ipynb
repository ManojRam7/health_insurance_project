# %%
# %run "/Users/manojrammopati/Public/Projects/bupa_insurance_project/_01_Bronze/Jupyter Notebooks/00_bronze_data_connector.ipynb"
# Out:
# 25/12/17 02:07:11 WARN Utils: Your hostname, Manojrams-MacBook-Air.local resolves to a loopback address: 127.0.0.1; using 192.168.0.219 instead (on interface en0)
# 25/12/17 02:07:11 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Ivy Default Cache set to: /Users/manojrammopati/.ivy2/cache
# The jars for the packages stored in: /Users/manojrammopati/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# org.apache.hadoop#hadoop-azure added as a dependency
# com.azure#azure-storage-blob added as a dependency
# com.azure#azure-identity added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-6a2a75ce-3859-437f-a9f5-3bf9a6c38208;1.0
# 	confs: [default]
# :: loading settings :: url = jar:file:/opt/anaconda3/envs/spark_local/lib/python3.10/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# 	found io.delta#delta-spark_2.12;3.1.0 in central
# 	found io.delta#delta-storage;3.1.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# 	found org.apache.hadoop#hadoop-azure;3.3.4 in central
# 	found org.apache.httpcomponents#httpclient;4.5.13 in central
# 	found org.apache.httpcomponents#httpcore;4.4.13 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found commons-codec#commons-codec;1.15 in central
# 	found com.microsoft.azure#azure-storage;7.0.1 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.12.7 in central
# 	found org.slf4j#slf4j-api;1.7.36 in central
# 	found com.microsoft.azure#azure-keyvault-core;1.0.0 in central
# 	found com.google.guava#guava;27.0-jre in central
# 	found com.google.guava#failureaccess;1.0 in central
# 	found com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found org.checkerframework#checker-qual;2.5.2 in central
# 	found com.google.errorprone#error_prone_annotations;2.2.0 in central
# 	found com.google.j2objc#j2objc-annotations;1.1 in central
# 	found org.codehaus.mojo#animal-sniffer-annotations;1.17 in central
# 	found org.apache.hadoop.thirdparty#hadoop-shaded-guava;1.1.1 in central
# 	found org.eclipse.jetty#jetty-util-ajax;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-util;9.4.43.v20210629 in central
# 	found org.codehaus.jackson#jackson-mapper-asl;1.9.13 in central
# 	found org.codehaus.jackson#jackson-core-asl;1.9.13 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.0.7.Final in central
# 	found com.azure#azure-storage-blob;12.19.0 in central
# 	found com.azure#azure-core;1.31.0 in central
# 	found com.fasterxml.jackson.core#jackson-annotations;2.13.3 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.13.3 in central
# 	found com.fasterxml.jackson.core#jackson-databind;2.13.3 in central
# 	found com.fasterxml.jackson.datatype#jackson-datatype-jsr310;2.13.3 in central
# 	found com.fasterxml.jackson.dataformat#jackson-dataformat-xml;2.13.3 in central
# 	found org.codehaus.woodstox#stax2-api;4.2.1 in central
# 	found com.fasterxml.woodstox#woodstox-core;6.2.7 in central
# 	found io.projectreactor#reactor-core;3.4.21 in central
# 	found org.reactivestreams#reactive-streams;1.0.4 in central
# 	found com.azure#azure-core-http-netty;1.12.4 in central
# 	found io.netty#netty-handler;4.1.79.Final in central
# 	found io.netty#netty-common;4.1.79.Final in central
# 	found io.netty#netty-resolver;4.1.79.Final in central
# 	found io.netty#netty-buffer;4.1.79.Final in central
# 	found io.netty#netty-transport;4.1.79.Final in central
# 	found io.netty#netty-transport-native-unix-common;4.1.79.Final in central
# 	found io.netty#netty-codec;4.1.79.Final in central
# 	found io.netty#netty-handler-proxy;4.1.79.Final in central
# 	found io.netty#netty-codec-socks;4.1.79.Final in central
# 	found io.netty#netty-codec-http;4.1.79.Final in central
# 	found io.netty#netty-codec-http2;4.1.79.Final in central
# 	found io.netty#netty-transport-native-epoll;4.1.79.Final in central
# 	found io.netty#netty-transport-classes-epoll;4.1.79.Final in central
# 	found io.netty#netty-transport-native-kqueue;4.1.79.Final in central
# 	found io.netty#netty-transport-classes-kqueue;4.1.79.Final in central
# 	found io.netty#netty-tcnative-boringssl-static;2.0.53.Final in central
# 	found io.netty#netty-tcnative-classes;2.0.53.Final in central
# 	found io.projectreactor.netty#reactor-netty-http;1.0.21 in central
# 	found io.netty#netty-resolver-dns;4.1.79.Final in central
# 	found io.netty#netty-codec-dns;4.1.79.Final in central
# 	found io.netty#netty-resolver-dns-native-macos;4.1.79.Final in central
# 	found io.netty#netty-resolver-dns-classes-macos;4.1.79.Final in central
# 	found io.projectreactor.netty#reactor-netty-core;1.0.21 in central
# 	found com.azure#azure-storage-common;12.18.0 in central
# 	found com.azure#azure-storage-internal-avro;12.4.1 in central
# 	found com.azure#azure-identity;1.10.0 in central
# 	found com.azure#azure-core;1.42.0 in central
# 	found com.azure#azure-json;1.0.1 in central
# 	found com.fasterxml.jackson.core#jackson-annotations;2.13.5 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.13.5 in central
# 	found com.fasterxml.jackson.core#jackson-databind;2.13.5 in central
# 	found com.fasterxml.jackson.datatype#jackson-datatype-jsr310;2.13.5 in central
# 	found io.projectreactor#reactor-core;3.4.30 in central
# 	found com.azure#azure-core-http-netty;1.13.6 in central
# 	found io.netty#netty-handler;4.1.94.Final in central
# 	found io.netty#netty-common;4.1.94.Final in central
# 	found io.netty#netty-resolver;4.1.94.Final in central
# 	found io.netty#netty-buffer;4.1.94.Final in central
# 	found io.netty#netty-transport;4.1.94.Final in central
# 	found io.netty#netty-transport-native-unix-common;4.1.94.Final in central
# 	found io.netty#netty-codec;4.1.94.Final in central
# 	found io.netty#netty-handler-proxy;4.1.94.Final in central
# 	found io.netty#netty-codec-socks;4.1.94.Final in central
# 	found io.netty#netty-codec-http;4.1.94.Final in central
# 	found io.netty#netty-codec-http2;4.1.94.Final in central
# 	found io.netty#netty-transport-native-epoll;4.1.94.Final in central
# 	found io.netty#netty-transport-classes-epoll;4.1.94.Final in central
# 	found io.netty#netty-transport-native-kqueue;4.1.94.Final in central
# 	found io.netty#netty-transport-classes-kqueue;4.1.94.Final in central
# 	found io.netty#netty-tcnative-boringssl-static;2.0.61.Final in central
# 	found io.netty#netty-tcnative-classes;2.0.61.Final in central
# 	found io.projectreactor.netty#reactor-netty-http;1.0.33 in central
# 	found io.netty#netty-resolver-dns;4.1.93.Final in central
# 	found io.netty#netty-codec-dns;4.1.93.Final in central
# 	found io.netty#netty-resolver-dns-native-macos;4.1.93.Final in central
# 	found io.netty#netty-resolver-dns-classes-macos;4.1.93.Final in central
# 	found io.projectreactor.netty#reactor-netty-core;1.0.33 in central
# 	found com.microsoft.azure#msal4j;1.13.9 in central
# 	found com.nimbusds#oauth2-oidc-sdk;10.7.1 in central
# 	found com.github.stephenc.jcip#jcip-annotations;1.0-1 in central
# 	found com.nimbusds#content-type;2.2 in central
# 	found com.nimbusds#lang-tag;1.7 in central
# 	found com.nimbusds#nimbus-jose-jwt;9.30.2 in central
# 	found net.minidev#json-smart;2.4.10 in central
# 	found net.minidev#accessors-smart;2.4.9 in central
# 	found org.ow2.asm#asm;9.3 in central
# 	found com.microsoft.azure#msal4j-persistence-extension;1.2.0 in central
# 	found net.java.dev.jna#jna;5.13.0 in central
# 	found net.java.dev.jna#jna-platform;5.6.0 in central
# :: resolution report :: resolve 1121ms :: artifacts dl 18ms
# 	:: modules in use:
# 	com.azure#azure-core;1.42.0 from central in [default]
# 	com.azure#azure-core-http-netty;1.13.6 from central in [default]
# 	com.azure#azure-identity;1.10.0 from central in [default]
# 	com.azure#azure-json;1.0.1 from central in [default]
# 	com.azure#azure-storage-blob;12.19.0 from central in [default]
# 	com.azure#azure-storage-common;12.18.0 from central in [default]
# 	com.azure#azure-storage-internal-avro;12.4.1 from central in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.13.5 from central in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.13.5 from central in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.13.5 from central in [default]
# 	com.fasterxml.jackson.datatype#jackson-datatype-jsr310;2.13.5 from central in [default]
# 	com.github.stephenc.jcip#jcip-annotations;1.0-1 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.errorprone#error_prone_annotations;2.2.0 from central in [default]
# 	com.google.guava#failureaccess;1.0 from central in [default]
# 	com.google.guava#guava;27.0-jre from central in [default]
# 	com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava from central in [default]
# 	com.google.j2objc#j2objc-annotations;1.1 from central in [default]
# 	com.microsoft.azure#azure-keyvault-core;1.0.0 from central in [default]
# 	com.microsoft.azure#azure-storage;7.0.1 from central in [default]
# 	com.microsoft.azure#msal4j;1.13.9 from central in [default]
# 	com.microsoft.azure#msal4j-persistence-extension;1.2.0 from central in [default]
# 	com.nimbusds#content-type;2.2 from central in [default]
# 	com.nimbusds#lang-tag;1.7 from central in [default]
# 	com.nimbusds#nimbus-jose-jwt;9.30.2 from central in [default]
# 	com.nimbusds#oauth2-oidc-sdk;10.7.1 from central in [default]
# 	commons-codec#commons-codec;1.15 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	io.delta#delta-spark_2.12;3.1.0 from central in [default]
# 	io.delta#delta-storage;3.1.0 from central in [default]
# 	io.netty#netty-buffer;4.1.94.Final from central in [default]
# 	io.netty#netty-codec;4.1.94.Final from central in [default]
# 	io.netty#netty-codec-dns;4.1.93.Final from central in [default]
# 	io.netty#netty-codec-http;4.1.94.Final from central in [default]
# 	io.netty#netty-codec-http2;4.1.94.Final from central in [default]
# 	io.netty#netty-codec-socks;4.1.94.Final from central in [default]
# 	io.netty#netty-common;4.1.94.Final from central in [default]
# 	io.netty#netty-handler;4.1.94.Final from central in [default]
# 	io.netty#netty-handler-proxy;4.1.94.Final from central in [default]
# 	io.netty#netty-resolver;4.1.94.Final from central in [default]
# 	io.netty#netty-resolver-dns;4.1.93.Final from central in [default]
# 	io.netty#netty-resolver-dns-classes-macos;4.1.93.Final from central in [default]
# 	io.netty#netty-resolver-dns-native-macos;4.1.93.Final from central in [default]
# 	io.netty#netty-tcnative-boringssl-static;2.0.61.Final from central in [default]
# 	io.netty#netty-tcnative-classes;2.0.61.Final from central in [default]
# 	io.netty#netty-transport;4.1.94.Final from central in [default]
# 	io.netty#netty-transport-classes-epoll;4.1.94.Final from central in [default]
# 	io.netty#netty-transport-classes-kqueue;4.1.94.Final from central in [default]
# 	io.netty#netty-transport-native-epoll;4.1.94.Final from central in [default]
# 	io.netty#netty-transport-native-kqueue;4.1.94.Final from central in [default]
# 	io.netty#netty-transport-native-unix-common;4.1.94.Final from central in [default]
# 	io.projectreactor#reactor-core;3.4.30 from central in [default]
# 	io.projectreactor.netty#reactor-netty-core;1.0.33 from central in [default]
# 	io.projectreactor.netty#reactor-netty-http;1.0.33 from central in [default]
# 	net.java.dev.jna#jna;5.13.0 from central in [default]
# 	net.java.dev.jna#jna-platform;5.6.0 from central in [default]
# 	net.minidev#accessors-smart;2.4.9 from central in [default]
# 	net.minidev#json-smart;2.4.10 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	org.apache.hadoop#hadoop-azure;3.3.4 from central in [default]
# 	org.apache.hadoop.thirdparty#hadoop-shaded-guava;1.1.1 from central in [default]
# 	org.apache.httpcomponents#httpclient;4.5.13 from central in [default]
# 	org.apache.httpcomponents#httpcore;4.4.13 from central in [default]
# 	org.checkerframework#checker-qual;2.5.2 from central in [default]
# 	org.codehaus.jackson#jackson-core-asl;1.9.13 from central in [default]
# 	org.codehaus.jackson#jackson-mapper-asl;1.9.13 from central in [default]
# 	org.codehaus.mojo#animal-sniffer-annotations;1.17 from central in [default]
# 	org.eclipse.jetty#jetty-util;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-util-ajax;9.4.43.v20210629 from central in [default]
# 	org.ow2.asm#asm;9.3 from central in [default]
# 	org.reactivestreams#reactive-streams;1.0.4 from central in [default]
# 	org.slf4j#slf4j-api;1.7.36 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.0.7.Final from central in [default]
# 	:: evicted modules:
# 	com.fasterxml.jackson.core#jackson-core;2.12.7 by [com.fasterxml.jackson.core#jackson-core;2.13.3] in [default]
# 	com.azure#azure-core;1.31.0 by [com.azure#azure-core;1.42.0] in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.13.3 by [com.fasterxml.jackson.core#jackson-annotations;2.13.5] in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.13.3 by [com.fasterxml.jackson.core#jackson-core;2.13.5] in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.13.3 by [com.fasterxml.jackson.core#jackson-databind;2.13.5] in [default]
# 	com.fasterxml.jackson.datatype#jackson-datatype-jsr310;2.13.3 by [com.fasterxml.jackson.datatype#jackson-datatype-jsr310;2.13.5] in [default]
# 	com.fasterxml.jackson.dataformat#jackson-dataformat-xml;2.13.3 transitively in [default]
# 	org.codehaus.woodstox#stax2-api;4.2.1 transitively in [default]
# 	com.fasterxml.woodstox#woodstox-core;6.2.7 transitively in [default]
# 	io.projectreactor#reactor-core;3.4.21 by [io.projectreactor#reactor-core;3.4.30] in [default]
# 	com.azure#azure-core-http-netty;1.12.4 by [com.azure#azure-core-http-netty;1.13.6] in [default]
# 	io.netty#netty-handler;4.1.79.Final by [io.netty#netty-handler;4.1.94.Final] in [default]
# 	io.netty#netty-common;4.1.79.Final by [io.netty#netty-common;4.1.94.Final] in [default]
# 	io.netty#netty-resolver;4.1.79.Final by [io.netty#netty-resolver;4.1.94.Final] in [default]
# 	io.netty#netty-buffer;4.1.79.Final by [io.netty#netty-buffer;4.1.94.Final] in [default]
# 	io.netty#netty-transport;4.1.79.Final by [io.netty#netty-transport;4.1.94.Final] in [default]
# 	io.netty#netty-transport-native-unix-common;4.1.79.Final by [io.netty#netty-transport-native-unix-common;4.1.94.Final] in [default]
# 	io.netty#netty-codec;4.1.79.Final by [io.netty#netty-codec;4.1.94.Final] in [default]
# 	io.netty#netty-handler-proxy;4.1.79.Final by [io.netty#netty-handler-proxy;4.1.94.Final] in [default]
# 	io.netty#netty-codec-socks;4.1.79.Final by [io.netty#netty-codec-socks;4.1.94.Final] in [default]
# 	io.netty#netty-codec-http;4.1.79.Final by [io.netty#netty-codec-http;4.1.94.Final] in [default]
# 	io.netty#netty-codec-http2;4.1.79.Final by [io.netty#netty-codec-http2;4.1.94.Final] in [default]
# 	io.netty#netty-transport-native-epoll;4.1.79.Final by [io.netty#netty-transport-native-epoll;4.1.94.Final] in [default]
# 	io.netty#netty-transport-classes-epoll;4.1.79.Final by [io.netty#netty-transport-classes-epoll;4.1.94.Final] in [default]
# 	io.netty#netty-transport-native-kqueue;4.1.79.Final by [io.netty#netty-transport-native-kqueue;4.1.94.Final] in [default]
# 	io.netty#netty-transport-classes-kqueue;4.1.79.Final by [io.netty#netty-transport-classes-kqueue;4.1.94.Final] in [default]
# 	io.netty#netty-tcnative-boringssl-static;2.0.53.Final by [io.netty#netty-tcnative-boringssl-static;2.0.61.Final] in [default]
# 	io.netty#netty-tcnative-classes;2.0.53.Final by [io.netty#netty-tcnative-classes;2.0.61.Final] in [default]
# 	io.projectreactor.netty#reactor-netty-http;1.0.21 by [io.projectreactor.netty#reactor-netty-http;1.0.33] in [default]
# 	io.netty#netty-resolver-dns;4.1.79.Final by [io.netty#netty-resolver-dns;4.1.93.Final] in [default]
# 	io.netty#netty-codec-dns;4.1.79.Final by [io.netty#netty-codec-dns;4.1.93.Final] in [default]
# 	io.netty#netty-resolver-dns-native-macos;4.1.79.Final by [io.netty#netty-resolver-dns-native-macos;4.1.93.Final] in [default]
# 	io.netty#netty-resolver-dns-classes-macos;4.1.79.Final by [io.netty#netty-resolver-dns-classes-macos;4.1.93.Final] in [default]
# 	io.projectreactor.netty#reactor-netty-core;1.0.21 by [io.projectreactor.netty#reactor-netty-core;1.0.33] in [default]
# 	io.projectreactor#reactor-core;3.4.20 by [io.projectreactor#reactor-core;3.4.21] in [default]
# 	io.netty#netty-codec-http;4.1.93.Final by [io.netty#netty-codec-http;4.1.94.Final] in [default]
# 	io.netty#netty-codec-http2;4.1.93.Final by [io.netty#netty-codec-http2;4.1.94.Final] in [default]
# 	io.netty#netty-common;4.1.93.Final by [io.netty#netty-common;4.1.94.Final] in [default]
# 	io.netty#netty-buffer;4.1.93.Final by [io.netty#netty-buffer;4.1.94.Final] in [default]
# 	io.netty#netty-resolver;4.1.93.Final by [io.netty#netty-resolver;4.1.94.Final] in [default]
# 	io.netty#netty-transport;4.1.93.Final by [io.netty#netty-transport;4.1.94.Final] in [default]
# 	io.netty#netty-codec;4.1.93.Final by [io.netty#netty-codec;4.1.94.Final] in [default]
# 	io.netty#netty-handler;4.1.93.Final by [io.netty#netty-handler;4.1.94.Final] in [default]
# 	io.netty#netty-transport-native-unix-common;4.1.93.Final by [io.netty#netty-transport-native-unix-common;4.1.94.Final] in [default]
# 	io.netty#netty-transport-native-epoll;4.1.93.Final by [io.netty#netty-transport-native-epoll;4.1.94.Final] in [default]
# 	io.netty#netty-handler-proxy;4.1.93.Final by [io.netty#netty-handler-proxy;4.1.94.Final] in [default]
# 	net.minidev#json-smart;[1.3.3,2.4.10] by [net.minidev#json-smart;2.4.10] in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.13.4.2 by [com.fasterxml.jackson.core#jackson-databind;2.13.5] in [default]
# 	com.microsoft.azure#msal4j;1.4.0 by [com.microsoft.azure#msal4j;1.13.9] in [default]
# 	net.java.dev.jna#jna-platform;5.13.0 by [net.java.dev.jna#jna-platform;5.6.0] in [default]
# 	org.slf4j#slf4j-api;1.7.7 by [org.slf4j#slf4j-api;1.7.36] in [default]
# 	net.java.dev.jna#jna;5.6.0 by [net.java.dev.jna#jna;5.13.0] in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |  125  |   0   |   0   |   52  ||   73  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-6a2a75ce-3859-437f-a9f5-3bf9a6c38208
# 	confs: [default]
# 	0 artifacts copied, 73 already retrieved (0kB/14ms)
# 25/12/17 02:07:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Preconnectors ran successfully and connected to 'clientdatastorage' storage accounts
# [Stage 0:>                                                          (0 + 1) / 1]
# Created 33 tables in bupa_gold database

# %%
# Cell 0 – Utils import (shared pattern)

import sys
import os
import importlib

# Path to the folder that contains utils_silver.py
# (adjust if your repo is in a different location)
project_root = "/Users/manojrammopati/Public/Projects/bupa_insurance_project"
silver_dir = os.path.join(project_root, "_02_Silver")

if silver_dir not in sys.path:
    sys.path.insert(0, silver_dir)

import utils_silver
importlib.reload(utils_silver)  # pick up edits during dev
from utils_silver import *

print("Imported utils_silver from:", utils_silver.__file__)
# Out:
# ✅ utils_silver.py loaded
# ✅ utils_silver.py loaded
# Imported utils_silver from: /Users/manojrammopati/Public/Projects/bupa_insurance_project/_02_Silver/utils_silver.py

# %% [markdown]
# # Cell 1 — Imports + load utils + paths + constants

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import *
from datetime import datetime



# Build paths from utils
paths_bronze, paths_silver, paths_gold = build_paths(storage_account1)

print("✅ Bronze paths loaded")
print(paths_bronze)
print("✅ Silver paths loaded")
print(paths_silver)
# Out:
# ✅ Bronze paths loaded
# {'policies': 'abfss://rawdata@clientdatastorage.dfs.core.windows.net/policies', 'members': 'abfss://rawdata@clientdatastorage.dfs.core.windows.net/members', 'claims': 'abfss://rawdata@clientdatastorage.dfs.core.windows.net/claims', 'providers': 'abfss://rawdata@clientdatastorage.dfs.core.windows.net/providers'}
# ✅ Silver paths loaded
# {'policies': 'abfss://silverdata@clientdatastorage.dfs.core.windows.net/policies', 'members': 'abfss://silverdata@clientdatastorage.dfs.core.windows.net/members', 'claims': 'abfss://silverdata@clientdatastorage.dfs.core.windows.net/claims', 'providers': 'abfss://silverdata@clientdatastorage.dfs.core.windows.net/providers', '_quarantine': 'abfss://silverdata@clientdatastorage.dfs.core.windows.net/_quarantine', '_metrics': 'abfss://silverdata@clientdatastorage.dfs.core.windows.net/_metrics', '_reference': 'abfss://silverdata@clientdatastorage.dfs.core.windows.net/reference', '_ref_dim_channel': 'abfss://silverdata@clientdatastorage.dfs.core.windows.net/reference/dim_channel', '_ref_dim_product_line': 'abfss://silverdata@clientdatastorage.dfs.core.windows.net/reference/dim_product_line'}

# %% [markdown]
# # Cell 2 — Read Bronze Policies (Delta) + cast/select

# %%
BRONZE_POLICIES_PATH = paths_bronze["policies"]
print("Reading bronze policies from:", BRONZE_POLICIES_PATH)

pol_bz = spark.read.format("delta").load(BRONZE_POLICIES_PATH)

pol = (pol_bz.select(
        F.col("Policy_ID").cast("string"),
        F.col("Customer_ID").cast("string"),
        F.col("Product_Line").cast("string"),
        F.col("Sum_Insured_GBP").cast("double"),
        F.col("Annual_Premium_GBP").cast("double"),
        F.to_date("Policy_Start_Date").alias("Policy_Start_Date"),
        F.to_date("Policy_End_Date").alias("Policy_End_Date"),
        F.col("Renewal_Offered_Flag").cast("int"),
        F.col("Renewal_Accepted_Flag").cast("int"),
        F.col("Discount_Offered_%").cast("double"),
        F.col("Channel").cast("string")
     ))

print(f"Bronze rowcount: {pol.count()}")
pol.show(5, truncate=False)
# Out:
# Reading bronze policies from: abfss://rawdata@clientdatastorage.dfs.core.windows.net/policies
# 25/12/17 02:07:39 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 40:==============>                                         (13 + 9) / 50]
# [Stage 40:===================================>                    (32 + 8) / 50]
# Bronze rowcount: 381109
# [Stage 52:=============================>                            (1 + 1) / 2]
# +----------+------------+------------+------------------+------------------+-----------------+---------------+--------------------+---------------------+------------------+-------+
# |Policy_ID |Customer_ID |Product_Line|Sum_Insured_GBP   |Annual_Premium_GBP|Policy_Start_Date|Policy_End_Date|Renewal_Offered_Flag|Renewal_Accepted_Flag|Discount_Offered_%|Channel|
# +----------+------------+------------+------------------+------------------+-----------------+---------------+--------------------+---------------------+------------------+-------+
# |P_00000001|CUST_0000001|Dental      |2193748.339982436 |40454.0           |2025-10-12       |2026-05-05     |1                   |0                    |3.418994275911136 |Partner|
# |P_00000002|CUST_0000002|Health      |1908192.4592739474|33536.0           |2025-06-04       |2026-08-23     |1                   |1                    |16.10228791601092 |Partner|
# |P_00000003|CUST_0000003|Health      |2356477.1034685415|38294.0           |2022-01-18       |2023-01-07     |1                   |1                    |11.551851153178037|Partner|
# |P_00000004|CUST_0000004|Health      |1715626.682311756 |28619.0           |2023-03-07       |2024-08-07     |1                   |1                    |18.952095739761848|Partner|
# |P_00000005|CUST_0000005|Dental      |1589495.8186594383|27496.0           |2024-03-20       |2025-08-07     |0                   |0                    |0.0               |Partner|
# +----------+------------+------------+------------------+------------------+-----------------+---------------+--------------------+---------------------+------------------+-------+
# only showing top 5 rows

# %%
# Cell 2 — Read Bronze policies and enforce schema

# 1) Read bronze Delta
pol_bz = spark.read.format("delta").load(BRONZE_POLICIES_PATH)

print("Bronze raw schema:")
pol_bz.printSchema()

# 2) Select & cast to clean schema columns
pol = (
    pol_bz.select(
        F.col("Policy_ID").cast("string"),
        F.col("Customer_ID").cast("string"),
        F.col("Product_Line").cast("string"),
        F.col("Sum_Insured_GBP").cast("double"),
        F.col("Annual_Premium_GBP").cast("double"),
        F.to_date("Policy_Start_Date").alias("Policy_Start_Date"),
        F.to_date("Policy_End_Date").alias("Policy_End_Date"),
        F.col("Renewal_Offered_Flag").cast("int"),
        F.col("Renewal_Accepted_Flag").cast("int"),
        F.col("Discount_Offered_%").cast("double"),
        F.col("Channel").cast("string"),
    )
)

print("Bronze (selected) rowcount:", pol.count())

# 3) Enforce strict target schema
policy_schema = StructType([
    StructField("Policy_ID",             StringType()),
    StructField("Customer_ID",           StringType()),
    StructField("Product_Line",          StringType()),
    StructField("Sum_Insured_GBP",       DoubleType()),
    StructField("Annual_Premium_GBP",    DoubleType()),
    StructField("Policy_Start_Date",     DateType()),
    StructField("Policy_End_Date",       DateType()),
    StructField("Renewal_Offered_Flag",  IntegerType()),
    StructField("Renewal_Accepted_Flag", IntegerType()),
    StructField("Discount_Offered_%",    DoubleType()),
    StructField("Channel",               StringType()),
])

pol = enforce_schema(pol, policy_schema)

print("After enforce_schema:")
pol.printSchema()
# Out:
# Bronze raw schema:
# root
#  |-- Policy_ID: string (nullable = true)
#  |-- Customer_ID: string (nullable = true)
#  |-- Product_Line: string (nullable = true)
#  |-- Sum_Insured_GBP: double (nullable = true)
#  |-- Annual_Premium_GBP: double (nullable = true)
#  |-- Policy_Start_Date: date (nullable = true)
#  |-- Policy_End_Date: date (nullable = true)
#  |-- Renewal_Offered_Flag: integer (nullable = true)
#  |-- Renewal_Accepted_Flag: integer (nullable = true)
#  |-- Discount_Offered_%: double (nullable = true)
#  |-- Channel: string (nullable = true)
# Bronze (selected) rowcount: 381109
# After enforce_schema:
# root
#  |-- Policy_ID: string (nullable = true)
#  |-- Customer_ID: string (nullable = true)
#  |-- Product_Line: string (nullable = true)
#  |-- Sum_Insured_GBP: double (nullable = true)
#  |-- Annual_Premium_GBP: double (nullable = true)
#  |-- Policy_Start_Date: date (nullable = true)
#  |-- Policy_End_Date: date (nullable = true)
#  |-- Renewal_Offered_Flag: integer (nullable = true)
#  |-- Renewal_Accepted_Flag: integer (nullable = true)
#  |-- Discount_Offered_%: double (nullable = true)
#  |-- Channel: string (nullable = true)

# %% [markdown]
# # 🔹 Cell 3 — Key checks & quarantine

# %%
# Cell 3 — Key checks (Policy_ID, Customer_ID) & quarantine

# Split OK vs BAD records by key presence
pol_bad = pol.filter(
    F.col("Policy_ID").isNull() | F.col("Customer_ID").isNull()
)

pol_ok = pol.filter(
    F.col("Policy_ID").isNotNull() & F.col("Customer_ID").isNotNull()
)

print("Total rows:", pol.count())
print("Rows with missing keys:", pol_bad.count())
print("Rows with valid keys:", pol_ok.count())

# Send bad rows to central quarantine table
if pol_bad.count() > 0:
    quarantine(pol_bad, "null_key_policy_or_customer", "policies")

print("✅ Key check & quarantine completed.")
# Out:
# Total rows: 381109
# Rows with missing keys: 0
# [Stage 69:======================================>                   (2 + 1) / 3]
# Rows with valid keys: 381109
# ✅ Key check & quarantine completed.

# %% [markdown]
# # 🔹 Cell 4 — Business-rule DQ flags (money, discount, renewal)

# %%
# Cell 4 — DQ flags: money, discount, renewal logic

pol_ok = (
    pol_ok
    .withColumn(
        "dq_money_valid",
        F.when(
            (F.col("Annual_Premium_GBP") >= 0) &
            (F.col("Sum_Insured_GBP") >= 0),
            1
        ).otherwise(0)
    )
    .withColumn(
        "dq_discount_valid",
        F.when(
            (F.col("Discount_Offered_%").between(0, 100)) |
            (F.col("Discount_Offered_%").isNull()),
            1
        ).otherwise(0)
    )
    .withColumn(
        "dq_renewal_valid",
        F.when(
            ~(
                (F.col("Renewal_Accepted_Flag") == 1) &
                (F.coalesce(F.col("Renewal_Offered_Flag"), F.lit(0)) != 1)
            ),
            1
        ).otherwise(0)
    )
)

print("Sample with DQ flags:")
pol_ok.select(
    "Policy_ID",
    "Annual_Premium_GBP",
    "Sum_Insured_GBP",
    "Discount_Offered_%",
    "Renewal_Offered_Flag",
    "Renewal_Accepted_Flag",
    "dq_money_valid",
    "dq_discount_valid",
    "dq_renewal_valid",
).show(10, truncate=False)
# Out:
# Sample with DQ flags:
# [Stage 79:=============================>                            (1 + 1) / 2]
# +----------+------------------+------------------+------------------+--------------------+---------------------+--------------+-----------------+----------------+
# |Policy_ID |Annual_Premium_GBP|Sum_Insured_GBP   |Discount_Offered_%|Renewal_Offered_Flag|Renewal_Accepted_Flag|dq_money_valid|dq_discount_valid|dq_renewal_valid|
# +----------+------------------+------------------+------------------+--------------------+---------------------+--------------+-----------------+----------------+
# |P_00000001|40454.0           |2193748.339982436 |3.418994275911136 |1                   |0                    |1             |1                |1               |
# |P_00000002|33536.0           |1908192.4592739474|16.10228791601092 |1                   |1                    |1             |1                |1               |
# |P_00000003|38294.0           |2356477.1034685415|11.551851153178037|1                   |1                    |1             |1                |1               |
# |P_00000004|28619.0           |1715626.682311756 |18.952095739761848|1                   |1                    |1             |1                |1               |
# |P_00000005|27496.0           |1589495.8186594383|0.0               |0                   |0                    |1             |1                |1               |
# |P_00000006|2630.0            |167095.0764838565 |4.187409955154    |1                   |0                    |1             |1                |1               |
# |P_00000007|23367.0           |1268428.5249639058|7.332844523589563 |1                   |1                    |1             |1                |1               |
# |P_00000008|32031.0           |2078401.4641741607|16.157376356743764|1                   |0                    |1             |1                |1               |
# |P_00000009|27619.0           |1441774.219193688 |14.270286866904922|1                   |1                    |1             |1                |1               |
# |P_00000010|28771.0           |1785268.5310676077|14.390651132612106|1                   |1                    |1             |1                |1               |
# +----------+------------------+------------------+------------------+--------------------+---------------------+--------------+-----------------+----------------+
# only showing top 10 rows

# %% [markdown]
# # 🔹 Cell 5 — Deduplicate, normalize, derive features

# %%
# Cell 5 — Deduplicate + normalize categories + derived columns

# Deduplicate per Policy_ID (latest by Policy_Start_Date)
pol_silver = drop_dupes_keep_latest(
    pol_ok,
    key_cols=["Policy_ID"],
    order_desc_cols=["Policy_Start_Date"]
)

# Normalize categories (case & whitespace)
pol_silver = (
    pol_silver
    .withColumn("Product_Line", F.initcap(F.trim(F.col("Product_Line"))))
    .withColumn("Channel",      F.initcap(F.trim(F.col("Channel"))))
)

# Derived feature: Policy duration
pol_silver = pol_silver.withColumn(
    "Policy_Duration_Days",
    F.when(
        F.col("Policy_Start_Date").isNotNull() &
        F.col("Policy_End_Date").isNotNull(),
        F.datediff("Policy_End_Date", "Policy_Start_Date")
    ).otherwise(F.lit(None).cast("int"))
)

# Derived feature: Renewal_Conversion (only meaningful when offer=1)
pol_silver = pol_silver.withColumn(
    "Renewal_Conversion",
    F.when(F.col("Renewal_Offered_Flag") == 1,
           F.col("Renewal_Accepted_Flag"))
     .otherwise(F.lit(None).cast("int"))
)

print("Sample Silver policies (post-feature-engineering):")
pol_silver.show(10, truncate=False)
# Out:
# Sample Silver policies (post-feature-engineering):
# [Stage 82:======================================>                   (2 + 1) / 3]
# +----------+------------+------------+------------------+------------------+-----------------+---------------+--------------------+---------------------+------------------+-------+--------------+-----------------+----------------+--------------------+------------------+
# |Policy_ID |Customer_ID |Product_Line|Sum_Insured_GBP   |Annual_Premium_GBP|Policy_Start_Date|Policy_End_Date|Renewal_Offered_Flag|Renewal_Accepted_Flag|Discount_Offered_%|Channel|dq_money_valid|dq_discount_valid|dq_renewal_valid|Policy_Duration_Days|Renewal_Conversion|
# +----------+------------+------------+------------------+------------------+-----------------+---------------+--------------------+---------------------+------------------+-------+--------------+-----------------+----------------+--------------------+------------------+
# |P_00000006|CUST_0000006|Dental      |167095.0764838565 |2630.0            |2025-09-23       |2026-10-22     |1                   |0                    |4.187409955154    |Partner|1             |1                |1               |394                 |0                 |
# |P_00000010|CUST_0000010|Dental      |1785268.5310676077|28771.0           |2025-06-30       |2026-10-26     |1                   |1                    |14.390651132612106|Partner|1             |1                |1               |483                 |1                 |
# |P_00000014|CUST_0000014|Motor       |1861493.573002186 |36770.0           |2022-01-11       |2023-02-16     |1                   |1                    |2.162982929235331 |Partner|1             |1                |1               |401                 |1                 |
# |P_00000015|CUST_0000015|Dental      |2982134.3741765874|46818.0           |2022-11-19       |2024-01-30     |1                   |1                    |6.724465961402344 |Partner|1             |1                |1               |437                 |1                 |
# |P_00000021|CUST_0000021|Health      |2065203.1200872269|41184.0           |2025-09-15       |2026-12-11     |1                   |1                    |10.179375136490439|Partner|1             |1                |1               |452                 |1                 |
# |P_00000029|CUST_0000029|Health      |1716798.3713895776|27946.0           |2024-07-07       |2025-05-25     |1                   |1                    |13.645295884571889|Partner|1             |1                |1               |322                 |1                 |
# |P_00000048|CUST_0000048|Motor       |1768631.753634457 |33761.0           |2024-12-30       |2025-11-22     |1                   |1                    |11.203922991189659|Partner|1             |1                |1               |327                 |1                 |
# |P_00000055|CUST_0000055|Dental      |2802533.2585918056|45415.0           |2025-02-01       |2026-03-25     |1                   |0                    |13.85604607264841 |Partner|1             |1                |1               |417                 |0                 |
# |P_00000059|CUST_0000059|Dental      |134162.17334576987|2630.0            |2025-01-07       |2025-09-05     |1                   |1                    |12.22103564832716 |Partner|1             |1                |1               |241                 |1                 |
# |P_00000060|CUST_0000060|Health      |1968845.9318964244|35463.0           |2021-03-23       |2022-04-20     |1                   |1                    |10.533006452965987|Partner|1             |1                |1               |393                 |1                 |
# +----------+------------+------------+------------------+------------------+-----------------+---------------+--------------------+---------------------+------------------+-------+--------------+-----------------+----------------+--------------------+------------------+
# only showing top 10 rows

# %% [markdown]
# # 🔹 Cell 6 — Reference dimensions (Channel & Product_Line)

# %%
# Cell 6 — Reference dimensions (Channel, Product_Line) on filesystem

# Base reference path in ADLS from utils
REF_BASE = paths_silver["_reference"]
dim_channel_path = REF_BASE.rstrip("/") + "/dim_channel"
dim_product_path = REF_BASE.rstrip("/") + "/dim_product_line"

print("REF_BASE:", REF_BASE)
print("dim_channel_path:", dim_channel_path)
print("dim_product_path:", dim_product_path)

# Dimension DataFrames
dim_channel = spark.createDataFrame(
    [("Agent",), ("Broker",), ("Online",), ("Partner",)],
    "Channel STRING"
)

dim_product_line = spark.createDataFrame(
    [("Accident",), ("Dental",), ("Health",), ("Motor",), ("Travel",)],
    "Product_Line STRING"
)

# Persist to Delta paths (optional but good for reuse)
(dim_channel.write
    .format("delta")
    .mode("overwrite")
    .option("overwriteSchema", "true")
    .save(dim_channel_path))

(dim_product_line.write
    .format("delta")
    .mode("overwrite")
    .option("overwriteSchema", "true")
    .save(dim_product_path))

print("✅ Reference dimensions written to ADLS.")

print("dim_channel preview:")
dim_channel.show()

print("dim_product_line preview:")
dim_product_line.show()
# Out:
# REF_BASE: abfss://silverdata@clientdatastorage.dfs.core.windows.net/reference
# dim_channel_path: abfss://silverdata@clientdatastorage.dfs.core.windows.net/reference/dim_channel
# dim_product_path: abfss://silverdata@clientdatastorage.dfs.core.windows.net/reference/dim_product_line
# [Stage 88:===============================================>        (42 + 8) / 50]
# [Stage 92:>                                                         (0 + 8) / 8]
# [Stage 92:=====================>                                    (3 + 5) / 8]
# [Stage 105:================================================>      (44 + 6) / 50]
# [Stage 109:=================================================>       (7 + 1) / 8]
# ✅ Reference dimensions written to ADLS.
# dim_channel preview:
# +-------+
# |Channel|
# +-------+
# |  Agent|
# | Broker|
# | Online|
# |Partner|
# +-------+
#
# dim_product_line preview:
# +------------+
# |Product_Line|
# +------------+
# |    Accident|
# |      Dental|
# |      Health|
# |       Motor|
# |      Travel|
# +------------+

# %% [markdown]
# # 🔹 Cell 7 — Strong DQ expectations & dictionary checks

# %%
# ==========================================
# Cell 7 — Data Quality (DQ) validations
# Uses dq_expect / dq_left_anti_ref from utils_silver
# ==========================================

from pyspark.sql import functions as F

# --- Normalize renewal flags to clean 0/1 ints ---
def to_flag(colname):
    s = F.lower(F.trim(F.col(colname).cast("string")))
    return (
        F.when(s.isin("1", "y", "yes", "true", "t", "on"), 1)
         .when(s.isin("0", "n", "no", "false", "f", "off"), 0)
         .otherwise(F.col(colname).cast("int"))
    )

pol_silver = (
    pol_silver
    .withColumn("Renewal_Offered_Flag",  to_flag("Renewal_Offered_Flag").cast("int"))
    .withColumn("Renewal_Accepted_Flag", to_flag("Renewal_Accepted_Flag").cast("int"))
)

# 1) Basic expectations (hard-error) — NOTE: matches utils_silver.dq_expect signature

dq_expect(
    pol_silver,
    "key_not_null",
    "Policy_ID IS NOT NULL AND Customer_ID IS NOT NULL",
    "error",
    "policies",
    paths_silver
)

dq_expect(
    pol_silver,
    "date_order",
    "Policy_Start_Date IS NULL OR Policy_End_Date IS NULL OR Policy_End_Date >= Policy_Start_Date",
    "error",
    "policies",
    paths_silver
)

dq_expect(
    pol_silver,
    "money_non_negative",
    "coalesce(Annual_Premium_GBP,0) >= 0 AND coalesce(Sum_Insured_GBP,0) >= 0",
    "error",
    "policies",
    paths_silver
)

dq_expect(
    pol_silver,
    "discount_bounds",
    "`Discount_Offered_%` IS NULL OR (`Discount_Offered_%` BETWEEN 0 AND 100)",
    "error",
    "policies",
    paths_silver
)

# 2) Renewal consistency — SLA-gated block (manual, not via dq_expect)

viol_df = pol_silver.filter(
    (F.col("Renewal_Accepted_Flag") == 1) &
    (F.coalesce(F.col("Renewal_Offered_Flag"), F.lit(0)) != 1)
)
viol_cnt = viol_df.count()
total    = pol_silver.count()
viol_pct = 0 if total == 0 else round(viol_cnt / total * 100.0, 4)

if viol_cnt > 0:
    # uses quarantine from utils_silver, which requires paths_silver
    quarantine(viol_df, "renewal_inconsistent", "policies", paths_silver)

print(f"[RECON] renewal_inconsistent: {viol_cnt}/{total} ({viol_pct}%)")

# Relaxed SLA to unblock; you can tighten later
SLA_PCT = 25.0
if viol_pct > SLA_PCT:
    raise Exception(f"DQ gate failed: policies · renewal_consistency {viol_pct}% > {SLA_PCT}%")
else:
    print("✅ DQ PASS [policies] renewal_consistency (within SLA)")

# 3) Dictionary-based validations (ERROR severity)
#    Uses dq_left_anti_ref from utils_silver, which also takes paths_silver

# dim_channel and dim_product_line should be defined in Cell 6
dq_left_anti_ref(
    pol_silver,
    dim_channel,
    "Channel",
    "Channel",
    "channel_in_dictionary",
    "error",
    "policies",
    paths_silver
)

dq_left_anti_ref(
    pol_silver,
    dim_product_line,
    "Product_Line",
    "Product_Line",
    "product_line_in_dictionary",
    "error",
    "policies",
    paths_silver
)
# Out:
# [Stage 127:======================================>                  (2 + 1) / 3]
# [Stage 135:======================================>                  (2 + 1) / 3]
# ✅ DQ PASS [policies] key_not_null
# [Stage 143:======================================>                  (2 + 1) / 3]
# [Stage 151:======================================>                  (2 + 1) / 3]
# ✅ DQ PASS [policies] date_order
# [Stage 159:======================================>                  (2 + 1) / 3]
# [Stage 167:======================================>                  (2 + 1) / 3]
# ✅ DQ PASS [policies] money_non_negative
# [Stage 175:======================================>                  (2 + 1) / 3]
# [Stage 183:======================================>                  (2 + 1) / 3]
# ✅ DQ PASS [policies] discount_bounds
# [Stage 191:======================================>                  (2 + 1) / 3]
# [Stage 199:======================================>                  (2 + 1) / 3]
# [Stage 208:======================================>                  (2 + 1) / 3]
# 25/12/17 02:08:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# [Stage 210:>                                                        (0 + 8) / 8]
# [Stage 210:=====================>                                   (3 + 5) / 8]
# [Stage 210:===================================>                     (5 + 3) / 8]
# [Stage 213:============================================>          (40 + 9) / 50]
# [Stage 220:=================================================>     (45 + 5) / 50]
# [Stage 226:======================================>                  (2 + 1) / 3]
# [QUARANTINE] renewal_inconsistent → abfss://silverdata@clientdatastorage.dfs.core.windows.net/_quarantine/policies/renewal_inconsistent (rows=66981)
# [RECON] renewal_inconsistent: 66981/381109 (17.5753%)
# ✅ DQ PASS [policies] renewal_consistency (within SLA)
# [Stage 234:======================================>                  (2 + 1) / 3]
# [Stage 245:======================================>                  (2 + 1) / 3]
# ✅ DQ PASS [policies] channel_in_dictionary
# [Stage 253:======================================>                  (2 + 1) / 3]
# [Stage 264:======================================>                  (2 + 1) / 3]
# ✅ DQ PASS [policies] product_line_in_dictionary

# %% [markdown]
#  # 🔹 Cell 8 — Write Silver policies (Delta path) + optional optimize

# %%
# Cell 8 — Write Silver policies (Delta) and optional OPTIMIZE

FULL_TABLE_NAME = "bupa_silver.policies"  # logical table name (optional)
SILVER_POLICIES_PATH = paths_silver["policies"]

print("Writing Silver policies to path:", SILVER_POLICIES_PATH)

# Use path-based write (always works), and optionally also register as table
(pol_silver.write
    .format("delta")
    .mode("overwrite")
    .option("overwriteSchema", "true")
    .save(SILVER_POLICIES_PATH))

print("✅ Silver policies written to Delta path.")

# (Optional) register as table on top of that path
spark.sql("CREATE DATABASE IF NOT EXISTS bupa_silver")
spark.sql("DROP TABLE IF EXISTS bupa_silver.policies")
spark.sql(f"""
    CREATE TABLE bupa_silver.policies
    USING DELTA
    LOCATION '{SILVER_POLICIES_PATH}'
""")

print("✅ Registered table: bupa_silver.policies")

# Optional: OPTIMIZE / ZORDER (if available)
try:
    optimize_zorder(FULL_TABLE_NAME, ["Policy_ID", "Policy_Start_Date"])
    print("✅ OPTIMIZE/ZORDER completed.")
except Exception as e:
    print("[WARN] OPTIMIZE skipped:", e)
# Out:
# Writing Silver policies to path: abfss://silverdata@clientdatastorage.dfs.core.windows.net/policies
# [Stage 279:======================================>                  (2 + 1) / 3]
# 25/12/17 02:08:47 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# [Stage 281:>                                                        (0 + 8) / 8]
# [Stage 281:==============>                                          (2 + 6) / 8]
# [Stage 281:=====================>                                   (3 + 5) / 8]
# [Stage 281:==========================================>              (6 + 2) / 8]
# [Stage 281:=================================================>       (7 + 1) / 8]
# ✅ Silver policies written to Delta path.
# ✅ Registered table: bupa_silver.policies
# [WARN] OPTIMIZE skipped: name 'optimize_zorder' is not defined

# %%
# Use Spark SQL from a Python cell and display the results
spark.sql("SELECT * FROM bupa_silver.policies LIMIT 5").show(truncate=False)
# Out:
# [Stage 293:>                                                        (0 + 1) / 1]
# +----------+------------+------------+------------------+------------------+-----------------+---------------+--------------------+---------------------+------------------+-------+--------------+-----------------+----------------+--------------------+------------------+
# |Policy_ID |Customer_ID |Product_Line|Sum_Insured_GBP   |Annual_Premium_GBP|Policy_Start_Date|Policy_End_Date|Renewal_Offered_Flag|Renewal_Accepted_Flag|Discount_Offered_%|Channel|dq_money_valid|dq_discount_valid|dq_renewal_valid|Policy_Duration_Days|Renewal_Conversion|
# +----------+------------+------------+------------------+------------------+-----------------+---------------+--------------------+---------------------+------------------+-------+--------------+-----------------+----------------+--------------------+------------------+
# |P_00000012|CUST_0000012|Health      |2450517.3545981646|48699.0           |2025-10-05       |2026-04-05     |0                   |0                    |0.0               |Partner|1             |1                |1               |182                 |NULL              |
# |P_00000020|CUST_0000020|Health      |1814570.2709660626|32363.0           |2023-10-10       |2024-08-15     |1                   |1                    |12.464335427839902|Partner|1             |1                |1               |310                 |1                 |
# |P_00000030|CUST_0000030|Dental      |1652726.2786353608|25679.0           |2025-06-04       |2026-11-17     |1                   |0                    |1.973133450781821 |Partner|1             |1                |1               |531                 |0                 |
# |P_00000032|CUST_0000032|Dental      |3184232.6765111634|57444.0           |2021-11-10       |2022-09-11     |0                   |0                    |0.0               |Partner|1             |1                |1               |305                 |NULL              |
# |P_00000039|CUST_0000039|Health      |2373740.957783007 |42297.0           |2024-12-05       |2025-11-25     |1                   |0                    |19.961562596206456|Partner|1             |1                |1               |355                 |0                 |
# +----------+------------+------------+------------------+------------------+-----------------+---------------+--------------------+---------------------+------------------+-------+--------------+-----------------+----------------+--------------------+------------------+

# %% [markdown]
# # 🔹 Cell 9 — Metrics (observability) to _metrics path

# %%
# Cell 9 — Run metrics & store to _metrics Delta

from datetime import datetime

def write_metric(name: str, value, context: str, paths_silver: dict):
    metrics_path = paths_silver["_metrics"]

    df_metric = spark.createDataFrame(
        [(name, str(value), context, datetime.utcnow())],
        "metric STRING, value STRING, context STRING, ts TIMESTAMP"
    )

    (df_metric.write
        .format("delta")
        .mode("append")
        .save(metrics_path))

    print(f"✅ metric written → {name}={value}, context={context}, path={metrics_path}")

# Write a couple of key metrics
write_metric("rowcount_policies_silver",
             pol_silver.count(),
             "policies_silver",
             paths_silver)

write_metric("distinct_policy_ids_silver",
             pol_silver.select("Policy_ID").distinct().count(),
             "policies_silver",
             paths_silver)

# Read back metrics
metrics_df = spark.read.format("delta").load(paths_silver["_metrics"])
metrics_df.orderBy(F.col("ts").desc()).show(truncate=False)
# Out:
# [Stage 296:======================================>                  (2 + 1) / 3]
# [Stage 304:=================================================>       (7 + 1) / 8]
# [Stage 307:============================================>          (40 + 8) / 50]
# ✅ metric written → rowcount_policies_silver=381109, context=policies_silver, path=abfss://silverdata@clientdatastorage.dfs.core.windows.net/_metrics
# [Stage 320:======================================>                  (2 + 1) / 3]
# [Stage 322:======================================>                  (2 + 1) / 3]
# ✅ metric written → distinct_policy_ids_silver=381109, context=policies_silver, path=abfss://silverdata@clientdatastorage.dfs.core.windows.net/_metrics
# [Stage 336:>                                                        (0 + 8) / 8]
# [Stage 336:=======>                                                 (1 + 7) / 8]
# +---------------------------------+------+------------------+--------------------------+
# |metric                           |value |context           |ts                        |
# +---------------------------------+------+------------------+--------------------------+
# |distinct_policy_ids_silver       |381109|policies_silver   |2025-12-17 02:09:07.807696|
# |rowcount_policies_silver         |381109|policies_silver   |2025-12-17 02:08:58.98708 |
# |distinct_policy_ids_silver       |381109|policies_silver   |2025-12-09 22:55:49.635329|
# |rowcount_policies_silver         |381109|policies_silver   |2025-12-09 22:55:38.929536|
# |distinct_member_ids_fact_members |381109|fact_members_gold |2025-12-09 02:18:45.65421 |
# |rowcount_fact_members            |381109|fact_members_gold |2025-12-09 02:18:36.010228|
# |distinct_policy_ids_fact_policies|381109|fact_policies_gold|2025-12-09 02:17:01.318206|
# |rowcount_fact_policies           |381109|fact_policies_gold|2025-12-09 02:16:52.132872|
# |distinct_claim_ids_fact_claims   |558211|gold_fact_claims  |2025-12-09 02:07:23.429299|
# |rowcount_fact_claims             |558211|gold_fact_claims  |2025-12-09 02:07:14.937071|
# |distinct_provider_ids_silver     |5393  |providers_silver  |2025-12-09 02:05:54.666641|
# |rowcount_providers_silver        |5393  |providers_silver  |2025-12-09 02:05:46.647625|
# |distinct_claim_ids               |558211|claims_silver     |2025-12-09 02:04:29.410469|
# |rowcount_claims_silver           |558211|claims_silver     |2025-12-09 02:04:19.412853|
# |distinct_member_ids              |381109|members_silver    |2025-12-09 02:02:19.616929|
# |rowcount_members_silver          |381109|members_silver    |2025-12-09 02:02:12.146351|
# |distinct_policy_ids_silver       |381109|policies_silver   |2025-12-09 01:59:45.503127|
# |rowcount_policies_silver         |381109|policies_silver   |2025-12-09 01:59:37.773724|
# |distinct_claim_ids_fact_claims   |558211|gold_fact_claims  |2025-12-09 01:06:42.553833|
# |rowcount_fact_claims             |558211|gold_fact_claims  |2025-12-09 01:06:33.607404|
# +---------------------------------+------+------------------+--------------------------+
# only showing top 20 rows

# %% [markdown]
# # 🔹 Cell 10 — Quick sanity peek at Silver policies

# %%
# Cell 10 — Sanity check Silver policies

sv = spark.read.format("delta").load(paths_silver["policies"])

print("Silver policies schema:")
sv.printSchema()

print("Sample Silver rows:")
sv.show(20, truncate=False)
# Out:
# Silver policies schema:
# root
#  |-- Policy_ID: string (nullable = true)
#  |-- Customer_ID: string (nullable = true)
#  |-- Product_Line: string (nullable = true)
#  |-- Sum_Insured_GBP: double (nullable = true)
#  |-- Annual_Premium_GBP: double (nullable = true)
#  |-- Policy_Start_Date: date (nullable = true)
#  |-- Policy_End_Date: date (nullable = true)
#  |-- Renewal_Offered_Flag: integer (nullable = true)
#  |-- Renewal_Accepted_Flag: integer (nullable = true)
#  |-- Discount_Offered_%: double (nullable = true)
#  |-- Channel: string (nullable = true)
#  |-- dq_money_valid: integer (nullable = true)
#  |-- dq_discount_valid: integer (nullable = true)
#  |-- dq_renewal_valid: integer (nullable = true)
#  |-- Policy_Duration_Days: integer (nullable = true)
#  |-- Renewal_Conversion: integer (nullable = true)
#
# Sample Silver rows:
# [Stage 339:>                                                        (0 + 1) / 1]
# +----------+------------+------------+------------------+------------------+-----------------+---------------+--------------------+---------------------+------------------+-------+--------------+-----------------+----------------+--------------------+------------------+
# |Policy_ID |Customer_ID |Product_Line|Sum_Insured_GBP   |Annual_Premium_GBP|Policy_Start_Date|Policy_End_Date|Renewal_Offered_Flag|Renewal_Accepted_Flag|Discount_Offered_%|Channel|dq_money_valid|dq_discount_valid|dq_renewal_valid|Policy_Duration_Days|Renewal_Conversion|
# +----------+------------+------------+------------------+------------------+-----------------+---------------+--------------------+---------------------+------------------+-------+--------------+-----------------+----------------+--------------------+------------------+
# |P_00000012|CUST_0000012|Health      |2450517.3545981646|48699.0           |2025-10-05       |2026-04-05     |0                   |0                    |0.0               |Partner|1             |1                |1               |182                 |NULL              |
# |P_00000020|CUST_0000020|Health      |1814570.2709660626|32363.0           |2023-10-10       |2024-08-15     |1                   |1                    |12.464335427839902|Partner|1             |1                |1               |310                 |1                 |
# |P_00000030|CUST_0000030|Dental      |1652726.2786353608|25679.0           |2025-06-04       |2026-11-17     |1                   |0                    |1.973133450781821 |Partner|1             |1                |1               |531                 |0                 |
# |P_00000032|CUST_0000032|Dental      |3184232.6765111634|57444.0           |2021-11-10       |2022-09-11     |0                   |0                    |0.0               |Partner|1             |1                |1               |305                 |NULL              |
# |P_00000039|CUST_0000039|Health      |2373740.957783007 |42297.0           |2024-12-05       |2025-11-25     |1                   |0                    |19.961562596206456|Partner|1             |1                |1               |355                 |0                 |
# |P_00000045|CUST_0000045|Dental      |1613732.4084646974|31136.0           |2020-12-27       |2021-12-13     |1                   |1                    |12.077431758552668|Partner|1             |1                |1               |351                 |1                 |
# |P_00000051|CUST_0000051|Health      |909619.2391465316 |15052.0           |2024-05-16       |2025-03-22     |1                   |1                    |3.1979146331471098|Partner|1             |1                |1               |310                 |1                 |
# |P_00000053|CUST_0000053|Health      |1340299.9288104526|25553.0           |2023-06-15       |2024-11-08     |1                   |0                    |1.699519543114103 |Partner|1             |1                |1               |512                 |0                 |
# |P_00000068|CUST_0000068|Health      |3395818.061292356 |66338.0           |2021-11-30       |2023-01-15     |1                   |1                    |18.20074058744771 |Partner|1             |1                |1               |411                 |1                 |
# |P_00000070|CUST_0000070|Health      |170802.6041502265 |2630.0            |2022-11-16       |2023-10-08     |0                   |1                    |0.0               |Partner|1             |1                |0               |326                 |NULL              |
# |P_00000085|CUST_0000085|Motor       |1879909.7807083733|29802.0           |2025-04-08       |2026-07-20     |0                   |1                    |0.0               |Partner|1             |1                |0               |468                 |NULL              |
# |P_00000086|CUST_0000086|Health      |1459339.686640981 |27756.0           |2022-12-23       |2024-02-15     |0                   |0                    |0.0               |Partner|1             |1                |1               |419                 |NULL              |
# |P_00000105|CUST_0000105|Health      |2374837.6517870747|43046.0           |2022-10-15       |2023-05-26     |1                   |1                    |15.459956003699052|Partner|1             |1                |1               |223                 |1                 |
# |P_00000110|CUST_0000110|Health      |168960.9776915972 |2630.0            |2025-10-27       |2026-11-11     |1                   |1                    |17.325827268095377|Partner|1             |1                |1               |380                 |1                 |
# |P_00000111|CUST_0000111|Health      |1606243.6197713641|31428.0           |2021-10-10       |2022-09-05     |1                   |1                    |14.653030325502119|Partner|1             |1                |1               |330                 |1                 |
# |P_00000117|CUST_0000117|Health      |161785.99882990672|2630.0            |2022-02-23       |2023-01-09     |1                   |1                    |0.8854462870484947|Partner|1             |1                |1               |320                 |1                 |
# |P_00000124|CUST_0000124|Accident    |2126112.4390330473|38232.0           |2023-11-22       |2025-01-07     |1                   |1                    |15.958007470831816|Partner|1             |1                |1               |412                 |1                 |
# |P_00000129|CUST_0000129|Dental      |148028.6974133537 |2630.0            |2024-01-31       |2025-07-07     |1                   |0                    |14.216976393333468|Partner|1             |1                |1               |523                 |0                 |
# |P_00000132|CUST_0000132|Motor       |1636174.661661591 |30005.0           |2024-08-15       |2025-05-24     |0                   |1                    |0.0               |Partner|1             |1                |0               |282                 |NULL              |
# |P_00000147|CUST_0000147|Health      |1701241.9278729057|33780.0           |2023-03-10       |2024-08-06     |0                   |1                    |0.0               |Partner|1             |1                |0               |515                 |NULL              |
# +----------+------------+------------+------------------+------------------+-----------------+---------------+--------------------+---------------------+------------------+-------+--------------+-----------------+----------------+--------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# # 🔍 Comparison Cells A–D (Bronze vs Silver differences)

# %% [markdown]
# # 🅰️ Cell A — Load & snapshot

# %%
from pyspark.sql import functions as F

# Load Bronze & Silver policies from paths
bronze_policies = spark.read.format("delta").load(paths_bronze["policies"])
silver_policies = spark.read.format("delta").load(paths_silver["policies"])

print("Bronze row count: ", bronze_policies.count())
print("Silver row count: ", silver_policies.count())

metrics_A = {
    "rows_bronze": bronze_policies.count(),
    "rows_silver": silver_policies.count(),
    "distinct_policy_id_bronze": bronze_policies.select("Policy_ID").distinct().count(),
    "distinct_policy_id_silver": silver_policies.select("Policy_ID").distinct().count(),
}

print("A) Snapshot metrics:")
for k, v in metrics_A.items():
    print(f"  {k}: {v}")
# Out:
# Bronze row count:  381109
# Silver row count:  381109
# [Stage 362:======================================>                  (2 + 1) / 3]
# [Stage 370:==============>                                          (2 + 6) / 8]
# [Stage 370:===================================>                     (5 + 3) / 8]
# A) Snapshot metrics:
#   rows_bronze: 381109
#   rows_silver: 381109
#   distinct_policy_id_bronze: 381109
#   distinct_policy_id_silver: 381109

# %% [markdown]
# # 🅱 Cell B — Data quality improvement (basic checks)

# %%
def pct(x, n):
    return 0.0 if n == 0 else round(100.0 * x / n, 4)

br = bronze_policies
sv = silver_policies

n_br = br.count()
n_sv = sv.count()

# --- Bronze ---
br_null_keys = br.filter(F.col("Policy_ID").isNull() | F.col("Customer_ID").isNull()).count()
br_bad_dates = br.filter(
    F.col("Policy_Start_Date").isNotNull() &
    F.col("Policy_End_Date").isNotNull() &
    (F.col("Policy_End_Date") < F.col("Policy_Start_Date"))
).count()

br_neg_money = br.filter(
    (F.col("Sum_Insured_GBP") < 0) | (F.col("Annual_Premium_GBP") < 0)
).count()

br_discount_out = br.filter(
    F.col("Discount_Offered_%").isNotNull() &
    ((F.col("Discount_Offered_%") < 0) | (F.col("Discount_Offered_%") > 100))
).count()

# --- Silver ---
sv_null_keys = sv.filter(F.col("Policy_ID").isNull() | F.col("Customer_ID").isNull()).count()
sv_bad_dates = sv.filter(
    F.col("Policy_Start_Date").isNotNull() &
    F.col("Policy_End_Date").isNotNull() &
    (F.col("Policy_End_Date") < F.col("Policy_Start_Date"))
).count()

sv_neg_money = sv.filter(
    (F.col("Sum_Insured_GBP") < 0) | (F.col("Annual_Premium_GBP") < 0)
).count()

sv_discount_out = sv.filter(
    F.col("Discount_Offered_%").isNotNull() &
    ((F.col("Discount_Offered_%") < 0) | (F.col("Discount_Offered_%") > 100))
).count()

dq_report = {
    "bronze_null_keys_pct":        pct(br_null_keys, n_br),
    "silver_null_keys_pct":        pct(sv_null_keys, n_sv),
    "bronze_bad_date_order_pct":   pct(br_bad_dates, n_br),
    "silver_bad_date_order_pct":   pct(sv_bad_dates, n_sv),
    "bronze_negative_money_pct":   pct(br_neg_money, n_br),
    "silver_negative_money_pct":   pct(sv_neg_money, n_sv),
    "bronze_discount_out_pct":     pct(br_discount_out, n_br),
    "silver_discount_out_pct":     pct(sv_discount_out, n_sv),
}

print("B) Data quality improvement (Bronze → Silver):")
for k, v in dq_report.items():
    print(f"  {k}: {v}%")
# Out:
# [Stage 392:======================================>                  (2 + 1) / 3]
# [Stage 409:===================================>                     (5 + 3) / 8]
# B) Data quality improvement (Bronze → Silver):
#   bronze_null_keys_pct: 0.0%
#   silver_null_keys_pct: 0.0%
#   bronze_bad_date_order_pct: 0.0%
#   silver_bad_date_order_pct: 0.0%
#   bronze_negative_money_pct: 0.0%
#   silver_negative_money_pct: 0.0%
#   bronze_discount_out_pct: 0.0%
#   silver_discount_out_pct: 0.0%

# %% [markdown]
# # 🅲 Cell C — Feature differences (incl. new Silver columns + business purpose)

# %%
# Column sets
bronze_cols = set(bronze_policies.columns)
silver_cols = set(silver_policies.columns)

new_features      = sorted(list(silver_cols - bronze_cols))   # only in Silver
dropped_features  = sorted(list(bronze_cols - silver_cols))   # only in Bronze
common_features   = sorted(list(bronze_cols & silver_cols))   # shared

print("C1) Column comparison:")
print("  New in Silver:   ", new_features)
print("  Dropped in Silver:", dropped_features)
print("  Common columns:  ", len(common_features))

# Data types
bronze_types = dict(bronze_policies.dtypes)
silver_types = dict(silver_policies.dtypes)

# Align on Policy_ID for accurate per-column comparison
bronze_aligned = bronze_policies.select("Policy_ID", *common_features).dropDuplicates(["Policy_ID"])
silver_aligned = silver_policies.select("Policy_ID", *common_features).dropDuplicates(["Policy_ID"])

joined = (
    bronze_aligned.alias("bz")
    .join(silver_aligned.alias("sv"), on="Policy_ID", how="outer")
)

print("\nC2) Per-column type & value changes for common columns:")
for col in common_features:
    bronze_type = bronze_types.get(col)
    silver_type = silver_types.get(col)
    type_changed = bronze_type != silver_type
    type_msg = (
        f"Type changed: {bronze_type} → {silver_type}"
        if type_changed else
        f"Type unchanged: {bronze_type}"
    )

    n_diff = (
        joined
        .filter(
            (joined[f"bz.{col}"].isNull() & joined[f"sv.{col}"].isNotNull()) |
            (joined[f"bz.{col}"].isNotNull() & joined[f"sv.{col}"].isNull()) |
            (joined[f"bz.{col}"] != joined[f"sv.{col}"])
        )
        .count()
    )

    if n_diff == 0 and not type_changed:
        print(f"  • '{col}' unchanged. {type_msg}")
    else:
        print(f"  • '{col}' transformed in {n_diff} policies. {type_msg}")
        sample_diff = (
            joined
            .filter(
                (joined[f"bz.{col}"].isNull() & joined[f"sv.{col}"].isNotNull()) |
                (joined[f"bz.{col}"].isNotNull() & joined[f"sv.{col}"].isNull()) |
                (joined[f"bz.{col}"] != joined[f"sv.{col}"])
            )
            .select("Policy_ID", F.col(f"bz.{col}").alias("bronze_value"),
                                F.col(f"sv.{col}").alias("silver_value"))
            .limit(5)
        )
        print(f"    Sample differences for '{col}':")
        sample_diff.show(truncate=False)

# ---- NEW: business-purpose explanations for *new* Silver features ----

feature_explanations = {
    # typical Silver enrichments for policies
    "Policy_Duration_Days": (
        "Number of days between Policy_Start_Date and Policy_End_Date. "
        "Used for contract tenure analytics and rate-per-day KPIs."
    ),
    "Renewal_Conversion": (
        "Derived flag where we only keep Renewal_Accepted_Flag when a renewal was actually offered. "
        "Used to calculate clean renewal conversion rates."
    ),
    "dq_money_valid": (
        "Data quality flag: 1 when monetary fields are non-negative. "
        "Helps monitor and explain outliers / bad source records."
    ),
    "dq_discount_valid": (
        "Data quality flag: 1 when Discount_Offered_% is between 0 and 100 or null. "
        "Prevents nonsense discount values from polluting downstream analytics."
    ),
    "dq_renewal_valid": (
        "Data quality flag: 1 when 'accepted' implies 'offered'. "
        "Captures logically inconsistent renewal records."
    ),
    "record_hash": (
        "SHA-256 hash of the row contents. Used for change data capture, de-duplication, "
        "and lineage/audit purposes."
    ),
    "created_at": (
        "Timestamp when this Silver record was created. Supports data freshness reporting and auditing."
    ),
    "source_system": (
        "Identifier for the upstream system or pipeline. Used for lineage, recon, and debugging."
    ),
}

print("\nC3) New Silver-only features (with business purpose):")
for col in new_features:
    reason = feature_explanations.get(
        col,
        "No specific description mapped; this is a Silver-only enrichment or technical column."
    )
    print(f"\n  ➕ '{col}' (business purpose): {reason}")
    # Show sample values
    silver_policies.select("Policy_ID", col).limit(5).show(truncate=False)
    
print("\nC4) Features dropped from Bronze in Silver (usually technical / redundant):")
for col in dropped_features:
    print(f"  ✂ '{col}' was dropped in Silver (likely redundant, low quality, or replaced by a derived field).")
# Out:
# C1) Column comparison:
#   New in Silver:    ['Policy_Duration_Days', 'Renewal_Conversion', 'dq_discount_valid', 'dq_money_valid', 'dq_renewal_valid']
#   Dropped in Silver: []
#   Common columns:   11
#
# C2) Per-column type & value changes for common columns:
# [Stage 424:===========>     (2 + 1) / 3][Stage 425:>                (0 + 7) / 8]
# [Stage 424:===========>     (2 + 1) / 3][Stage 425:====>            (2 + 6) / 8]
# [Stage 424:======================================>                  (2 + 1) / 3]
# [Stage 428:=======>                                                 (1 + 7) / 8]
#   • 'Annual_Premium_GBP' unchanged. Type unchanged: double
# [Stage 437:===========>     (2 + 1) / 3][Stage 438:>                (0 + 7) / 8]
# [Stage 437:===========>     (2 + 1) / 3][Stage 438:======>          (3 + 5) / 8]
# [Stage 438:============================>                            (4 + 4) / 8]
# [Stage 438:=================================================>       (7 + 1) / 8]
#   • 'Channel' unchanged. Type unchanged: string
# [Stage 450:===========>     (2 + 1) / 3][Stage 451:>                (0 + 7) / 8]
# [Stage 450:===========>     (2 + 1) / 3][Stage 451:======>          (3 + 5) / 8]
# [Stage 450:===========>     (2 + 1) / 3][Stage 451:============>    (6 + 2) / 8]
# [Stage 450:===========>     (2 + 1) / 3][Stage 451:==============>  (7 + 1) / 8]
# [Stage 450:======================================>                  (2 + 1) / 3]
#   • 'Customer_ID' unchanged. Type unchanged: string
# [Stage 463:===========>     (2 + 1) / 3][Stage 464:==>              (1 + 7) / 8]
# [Stage 463:===========>     (2 + 1) / 3][Stage 464:======>          (3 + 5) / 8]
# [Stage 463:===========>     (2 + 1) / 3][Stage 464:========>        (4 + 4) / 8]
# [Stage 463:======================================>                  (2 + 1) / 3]
#   • 'Discount_Offered_%' unchanged. Type unchanged: double
# [Stage 476:======================================>                  (2 + 1) / 3]
# [Stage 476:===========>     (2 + 1) / 3][Stage 477:======>          (3 + 5) / 8]
# [Stage 476:======================================>                  (2 + 1) / 3]
# [Stage 480:==========================================>              (6 + 2) / 8]
#   • 'Policy_End_Date' unchanged. Type unchanged: date
# [Stage 489:===========>     (2 + 1) / 3][Stage 490:>                (0 + 7) / 8]
# [Stage 489:===========>     (2 + 1) / 3][Stage 490:====>            (2 + 6) / 8]
# [Stage 490:=====================>                                   (3 + 5) / 8]
# [Stage 490:==========================================>              (6 + 2) / 8]
#   • 'Policy_ID' unchanged. Type unchanged: string
# [Stage 502:===========>     (2 + 1) / 3][Stage 503:====>            (2 + 6) / 8]
# [Stage 503:==========================================>              (6 + 2) / 8]
# [Stage 503:=================================================>       (7 + 1) / 8]
#   • 'Policy_Start_Date' unchanged. Type unchanged: date
# [Stage 515:===========>     (2 + 1) / 3][Stage 516:>                (0 + 7) / 8]
# [Stage 515:===========>     (2 + 1) / 3][Stage 516:==>              (1 + 7) / 8]
# [Stage 515:===========>     (2 + 1) / 3][Stage 516:======>          (3 + 5) / 8]
# [Stage 515:===========>     (2 + 1) / 3][Stage 516:============>    (6 + 2) / 8]
# [Stage 515:======================================>                  (2 + 1) / 3]
#   • 'Product_Line' unchanged. Type unchanged: string
# [Stage 528:===========>     (2 + 1) / 3][Stage 529:====>            (2 + 6) / 8]
# [Stage 528:===========>     (2 + 1) / 3][Stage 529:======>          (3 + 5) / 8]
# [Stage 529:============================>                            (4 + 4) / 8]
# [Stage 529:=================================================>       (7 + 1) / 8]
#   • 'Renewal_Accepted_Flag' unchanged. Type unchanged: int
# [Stage 541:===========>     (2 + 1) / 3][Stage 542:>                (0 + 7) / 8]
# [Stage 541:===========>     (2 + 1) / 3][Stage 542:======>          (3 + 5) / 8]
# [Stage 541:===========>     (2 + 1) / 3][Stage 542:========>        (4 + 4) / 8]
# [Stage 542:==========================================>              (6 + 2) / 8]
#   • 'Renewal_Offered_Flag' unchanged. Type unchanged: int
# [Stage 554:===========>     (2 + 1) / 3][Stage 555:>                (0 + 7) / 8]
# [Stage 554:===========>     (2 + 1) / 3][Stage 555:====>            (2 + 6) / 8]
# [Stage 554:===========>     (2 + 1) / 3][Stage 555:========>        (4 + 4) / 8]
# [Stage 554:===========>     (2 + 1) / 3][Stage 555:============>    (6 + 2) / 8]
# [Stage 554:======================================>                  (2 + 1) / 3]
#   • 'Sum_Insured_GBP' unchanged. Type unchanged: double
#
# C3) New Silver-only features (with business purpose):
#
#   ➕ 'Policy_Duration_Days' (business purpose): Number of days between Policy_Start_Date and Policy_End_Date. Used for contract tenure analytics and rate-per-day KPIs.
# +----------+--------------------+
# |Policy_ID |Policy_Duration_Days|
# +----------+--------------------+
# |P_00000012|182                 |
# |P_00000020|310                 |
# |P_00000030|531                 |
# |P_00000032|305                 |
# |P_00000039|355                 |
# +----------+--------------------+
#
#
#   ➕ 'Renewal_Conversion' (business purpose): Derived flag where we only keep Renewal_Accepted_Flag when a renewal was actually offered. Used to calculate clean renewal conversion rates.
# +----------+------------------+
# |Policy_ID |Renewal_Conversion|
# +----------+------------------+
# |P_00000012|NULL              |
# |P_00000020|1                 |
# |P_00000030|0                 |
# |P_00000032|NULL              |
# |P_00000039|0                 |
# +----------+------------------+
#
#
#   ➕ 'dq_discount_valid' (business purpose): Data quality flag: 1 when Discount_Offered_% is between 0 and 100 or null. Prevents nonsense discount values from polluting downstream analytics.
# +----------+-----------------+
# |Policy_ID |dq_discount_valid|
# +----------+-----------------+
# |P_00000012|1                |
# |P_00000020|1                |
# |P_00000030|1                |
# |P_00000032|1                |
# |P_00000039|1                |
# +----------+-----------------+
#
#
#   ➕ 'dq_money_valid' (business purpose): Data quality flag: 1 when monetary fields are non-negative. Helps monitor and explain outliers / bad source records.
# +----------+--------------+
# |Policy_ID |dq_money_valid|
# +----------+--------------+
# |P_00000012|1             |
# |P_00000020|1             |
# |P_00000030|1             |
# |P_00000032|1             |
# |P_00000039|1             |
# +----------+--------------+
#
#
#   ➕ 'dq_renewal_valid' (business purpose): Data quality flag: 1 when 'accepted' implies 'offered'. Captures logically inconsistent renewal records.
# +----------+----------------+
# |Policy_ID |dq_renewal_valid|
# +----------+----------------+
# |P_00000012|1               |
# |P_00000020|1               |
# |P_00000030|1               |
# |P_00000032|1               |
# |P_00000039|1               |
# +----------+----------------+
#
#
# C4) Features dropped from Bronze in Silver (usually technical / redundant):

# %% [markdown]
# # 🅳 Cell D — Optional FK progress vs Members (if members_silver exists)

# %%
# Optional – only run if members Silver is ready
from pyspark.sql import functions as F

def canon(col):
    return F.upper(F.regexp_replace(F.trim(F.col(col)), r"[^A-Z0-9_]", ""))

try:
    mem = spark.read.format("delta").load(paths_silver["members"]) \
                    .select(canon("Policy_ID").alias("Policy_ID_canon")) \
                    .dropDuplicates()

    br_fk_miss = (
        br.withColumn("Policy_ID_canon", canon("Policy_ID"))
          .join(mem, "Policy_ID_canon", "left_anti")
    ).count()
    br_fk_pct = pct(br_fk_miss, br.count())

    sv_fk_miss = (
        sv.withColumn("Policy_ID_canon", canon("Policy_ID"))
          .join(mem, "Policy_ID_canon", "left_anti")
    ).count()
    sv_fk_pct = pct(sv_fk_miss, sv.count())

    print("D) FK quality vs Members (Bronze vs Silver):")
    print(f"  bronze_fk_missing_pct: {br_fk_pct}%")
    print(f"  silver_fk_missing_pct: {sv_fk_pct}%")
except Exception as e:
    print("[WARN] Members silver not available or FK check failed:", e)
# Out:
# [Stage 584:======================================>                  (2 + 1) / 3]
# [Stage 587:======================================>                  (2 + 1) / 3]
# [Stage 599:======================================>                  (2 + 1) / 3]
# [Stage 602:==============>                                          (2 + 6) / 8]
# [Stage 602:============================>                            (4 + 4) / 8]
# [Stage 602:===================================>                     (5 + 3) / 8]
# D) FK quality vs Members (Bronze vs Silver):
#   bronze_fk_missing_pct: 0.0%
#   silver_fk_missing_pct: 0.0%
