# %%
# %%capture
import os
import sys

# Suppress all output at environment level
os.environ['PYTHONWARNINGS'] = 'ignore'
os.environ['SPARK_LOCAL_IP'] = '127.0.0.1'
os.environ['IVY_CACHE_DIR'] = '/tmp/.ivy2_cache'

from pyspark.sql import SparkSession

packages = ",".join([
    "io.delta:delta-spark_2.12:3.1.0",                 # Delta Lake (compatible with Spark 3.5.7)
    "org.apache.hadoop:hadoop-azure:3.3.4",            # ADLS Gen2 connector
    "com.azure:azure-storage-blob:12.19.0",            # Blob SDK
    "com.azure:azure-identity:1.10.0"                  # Azure OAuth support
])

# Add Maven Central as primary repository (works online)
spark = (
    SparkSession.builder
        .appName("bupa-local-adls-delta")
        .master("local[*]")
        .config("spark.jars.packages", packages)
        .config("spark.jars.repositories", "https://repo1.maven.org/maven2/")
        .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
        .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
        .config("spark.driver.bindAddress", "127.0.0.1")
        .config("spark.ui.port", "0")  # Use any available port
        .getOrCreate()
)

# Suppress Spark logging
spark.sparkContext.setLogLevel("ERROR")
# Out:
# Picked up JAVA_TOOL_OPTIONS: -Dlog4j.configuration=file:///dev/null -Dlog4j.rootLogger=ERROR
# Picked up JAVA_TOOL_OPTIONS: -Dlog4j.configuration=file:///dev/null -Dlog4j.rootLogger=ERROR
# ERROR StatusLogger Reconfiguration failed: No configuration found for '5ffd2b27' at 'null' in 'null'
# ERROR StatusLogger Reconfiguration failed: No configuration found for 'Default' at 'null' in 'null'
# https://repo1.maven.org/maven2/ added as a remote repository with the name: repo-1
# Ivy Default Cache set to: /Users/manojrammopati/.ivy2/cache
# The jars for the packages stored in: /Users/manojrammopati/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# org.apache.hadoop#hadoop-azure added as a dependency
# com.azure#azure-storage-blob added as a dependency
# com.azure#azure-identity added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-724154c5-6f93-40e6-a88e-5591e41819cb;1.0
# 	confs: [default]
# ...

# %% [markdown]
# # storage account 1

# %%
# Databricks notebook source
# "Bupaclien data storage" account connector

storage_account1 = "clientdatastorage"
application_id = "1ccf404f-9af5-419e-b523-ce4938f86819"
directory_id = "f8409476-1122-4942-b791-4e484525ebe2"
client_secret = "92e8Q~Fu7w1QruXhccfih1XQQ5cA..JqhKPuSayS"

spark.conf.set(f"fs.azure.account.auth.type.{storage_account1}.dfs.core.windows.net", "OAuth")
spark.conf.set(f"fs.azure.account.oauth.provider.type.{storage_account1}.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set(f"fs.azure.account.oauth2.client.id.{storage_account1}.dfs.core.windows.net", application_id)
spark.conf.set(f"fs.azure.account.oauth2.client.secret.{storage_account1}.dfs.core.windows.net", client_secret)
spark.conf.set(f"fs.azure.account.oauth2.client.endpoint.{storage_account1}.dfs.core.windows.net", f"https://login.microsoftonline.com/{directory_id}/oauth2/token")
