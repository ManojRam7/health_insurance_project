# %%
# Databricks notebook source# "Bupaclientstorage" account connectorstorage_account1 = "bupaclientstorage"application_id = "c1ac2cb1-5983-4030-9bce-fd0a06a634ed"directory_id = "bb7aa9c6-f4bf-41ef-879a-fac0a8a74589"spark.conf.set(f"fs.azure.account.auth.type.{storage_account1}.dfs.core.windows.net", "OAuth")spark.conf.set(f"fs.azure.account.oauth.provider.type.{storage_account1}.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")spark.conf.set(f"fs.azure.account.oauth2.client.id.{storage_account1}.dfs.core.windows.net", application_id)spark.conf.set(f"fs.azure.account.oauth2.client.secret.{storage_account1}.dfs.core.windows.net", "CNm8Q~7t1QJ6OQta6M1piy5fu7X-yYnznuZtXdkJ")spark.conf.set(f"fs.azure.account.oauth2.client.endpoint.{storage_account1}.dfs.core.windows.net", f"https://login.microsoftonline.com/{directory_id}/oauth2/token")

# %%
# "Bupaprocesseddatastorage" account connectorstorage_account2 = "bupaprocesseddatastorage"application_id = "c1ac2cb1-5983-4030-9bce-fd0a06a634ed"directory_id = "bb7aa9c6-f4bf-41ef-879a-fac0a8a74589"spark.conf.set(f"fs.azure.account.auth.type.{storage_account2}.dfs.core.windows.net", "OAuth")spark.conf.set(f"fs.azure.account.oauth.provider.type.{storage_account2}.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")spark.conf.set(f"fs.azure.account.oauth2.client.id.{storage_account2}.dfs.core.windows.net", application_id)spark.conf.set(f"fs.azure.account.oauth2.client.secret.{storage_account2}.dfs.core.windows.net", "CNm8Q~7t1QJ6OQta6M1piy5fu7X-yYnznuZtXdkJ")spark.conf.set(f"fs.azure.account.oauth2.client.endpoint.{storage_account2}.dfs.core.windows.net", f"https://login.microsoftonline.com/{directory_id}/oauth2/token")

# %%
print(f"Preconnectors ran successfully and connected to '{storage_account1}' and '{storage_account2}' storage accounts")
